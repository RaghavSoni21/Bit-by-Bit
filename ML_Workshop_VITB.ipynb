# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavSoni21/Bit-by-Bit/blob/main/ML_Workshop_VITB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
from google.colab import drive
drive.mount("/content/gdrive/") # Mounting Google Drive with the code
# Out:
# Mounted at /content/gdrive/

# %%
path = "/content/gdrive/My Drive/Real Life Data/"
x_train=np.load(path+"X_Train_new2.npy")
y_train=np.load(path+"Y_train.npy")

print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (90, 30000)
# (90, 1)

# %%
plt.imshow(x_train[0].reshape(100,100,3))

# %%
plt.imshow(x_train[-1].reshape(100,100,3))

# %%
plt.imshow(x_train[-3].reshape(100,100,3))

# %% [markdown]
# ###Create Model

# %%
knn=KNeighborsClassifier()
# Train
knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make Predictions / Testing the Model
knn.predict(x_train[5].reshape(1,-1)) # As knn inputs 2D data therfore we reshaped it
# Out:
# array([0.])

# %%
plt.imshow(x_train[5].reshape(100,100,3))

# %%
# Making Prediction
knn.predict(x_train[:5]) # When range is given it automatically becomes 2D
# Out:
# array([0., 0., 0., 0., 0.])

# %%
y_train[:5] # Hence Model is Working
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])
